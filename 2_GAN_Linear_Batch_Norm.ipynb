# %% [markdown]
# # Select TensorFlow 1

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
from tensorflow.layers import conv2d, conv2d_transpose, batch_normalization,flatten, dense
from tensorflow.nn import tanh, sigmoid, leaky_relu, sigmoid_cross_entropy_with_logits
from tensorflow.train import AdamOptimizer

# %% [markdown]
# # Defining model layers

# %% [markdown]
# ### Defining generator model for the GAN

# %%
def generator(x, isTrain=True, reuse=False):
    with tf.variable_scope('generator', reuse=reuse):

        dense1 = dense(x, 128, activation=None)
        norm1 = batch_normalization(dense1, training=True)
        relu1 = leaky_relu(norm1)

        dense2 = dense(relu1, 128, activation=None)
        norm2 = batch_normalization(dense2, training=True)
        relu2 = leaky_relu(norm2)

        dense3 = dense(relu2, 64*64)
        output = tf.reshape(dense3, [-1, 64, 64, 1])
    return output

# %% [markdown]
# ### Defining discriminator model for the GAN

# %%
def discriminator(x, isTrain=True, reuse=False):
    with tf.variable_scope('discriminator', reuse=reuse):
        x = flatten(x)
        dense1 = dense(x, 128, activation=None)
        norm1 = batch_normalization(dense1, training=True)
        relu1 = leaky_relu(norm1)

        dense2 = dense(relu1, 128,activation=None)
        norm2 = batch_normalization(dense2, training=True)
        relu2 = leaky_relu(norm2)

        dense3 =  dense(relu2,2)
        out = dense(dense3,1)
        
    return out, dense3

# %% [markdown]
# # Defining GAN models

# %%
def create_GAN(x, z, isTrain):
  G_sample = generator(z, isTrain)
  D_real, D_real_logits= discriminator(x, isTrain)
  D_fake, D_fake_logits = discriminator(G_sample, isTrain, reuse=True)
  return G_sample, D_real, D_real_logits ,D_fake, D_fake_logits

# %% [markdown]
# # Defining losses for the network models

# %%
def create_loss_functions(D_real_logits, D_fake_logits, batch_size):
  D_loss_real = tf.reduce_mean(
      sigmoid_cross_entropy_with_logits(logits=D_real_logits, labels=tf.ones_like(D_real_logits)))
  D_loss_fake = tf.reduce_mean(
      sigmoid_cross_entropy_with_logits(logits=D_fake_logits, labels=tf.zeros_like(D_fake_logits)))
  D_loss = D_loss_real + D_loss_fake
  G_loss = tf.reduce_mean(
      sigmoid_cross_entropy_with_logits(logits=D_fake_logits, labels=tf.ones_like(D_fake_logits)))
  return D_loss, G_loss

# %% [markdown]
# # Util functions

# %%
#Define the plot of sample result function
def plot_samples(samples, epoch=None, n=5):
  if epoch == None:
    epoch = np.shape(samples)[0]-1
  fig = plt.figure(figsize=(8, 8))
  for i in range(n*n):
      ax = plt.subplot(n, n, i + 1)
      ax.imshow(samples[epoch][i].reshape(64,64))
      ax.axis("off")
  fig.subplots_adjust(hspace=0.025, wspace=0.025)
  plt.show()

# %%
#Define the plot of the training loss
def plot_training_loss(training_loss):
  plt.plot(training_loss['G_losses'], label='G_loss' )
  plt.plot(training_loss['D_losses'], label='D_loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(loc=1)
  plt.grid(True) 
  plt.show()

# %% [markdown]
# # Loading data, defining training parameters and input variables

# %%
# training parameters
batch_size = 100
lr = 0.001
num_epochs = 100
d_iterations = 5
g_iterations = 50

# load MNIST
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True, reshape=[])

# input variables
x = tf.placeholder(tf.float32, shape=(None, 64, 64, 1))
z = tf.placeholder(tf.float32, shape=(None, 1, 1, 100))
isTrain = tf.placeholder(dtype=tf.bool)
# Out:
# WARNING:tensorflow:From <ipython-input-9-be21158cb504>:9: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# # Initializing the GAN network

# %%
#Create GAN 
G_z, D_real, D_real_logits, D_fake, D_fake_logits = create_GAN(x, z, isTrain)
# Out:
# WARNING:tensorflow:From <ipython-input-3-413fbdd9f1b8>:4: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From <ipython-input-3-413fbdd9f1b8>:5: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# WARNING:tensorflow:From <ipython-input-4-15436bb75804>:3: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.

# %% [markdown]
# # Initializing losses for each network

# %%
#Create loss function for each network
D_loss, G_loss = create_loss_functions(D_real_logits,D_fake_logits,batch_size)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# # Model Setup

# %%
# trainable variables for each network
T_vars = tf.trainable_variables()
D_vars = [var for var in T_vars if var.name.startswith('discriminator')]
G_vars = [var for var in T_vars if var.name.startswith('generator')]

# Optimizer for each network
with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
    D_optim = tf.train.AdamOptimizer(lr).minimize(D_loss, var_list=D_vars)
    G_optim = tf.train.AdamOptimizer(lr).minimize(G_loss, var_list=G_vars)

# open session and initialize all variables
sess = tf.InteractiveSession()
tf.global_variables_initializer().run()


# Resize the data to be 64 * 64
train_set = tf.image.resize_images(mnist.train.images, [64, 64]).eval()

# Normalize the data to be from -1:1 
train_set = (train_set - 0.5) * 2 

#Initialize the training loss 
training_loss = {}
training_loss['D_losses'] = []
training_loss['G_losses'] = []

#Take a slice of the data to train on it to reduce the time of the training 
data_slice = 2000
train_set = train_set[:data_slice,:]

#Initialize the training loss 
training_loss = {}
training_loss['D_losses'] = []
training_loss['G_losses'] = []

#Initialize samples that will be used for ploting
samples=[]

# %% [markdown]
# # Training model

# %%
#Loop over the number of epochs 
for epoch in range(num_epochs):
    #Initialize discriminator loss (D_losses) and generator loss (G_losses) with an empty list in each epoch
    D_losses = []
    G_losses = []

    #Loop over the number of mini batches 
    mini_batches = train_set.shape[0] // batch_size
    for batch in range(mini_batches):

      x_batch = train_set[batch*batch_size:(batch+1)*batch_size]
      
      for _ in range(d_iterations):
        #Update discriminator, calculate and append its loss
        z_batch = np.random.normal(0, 1, (batch_size, 1, 1, 100))
        dloss, _ = sess.run([D_loss, D_optim], {x: x_batch, z: z_batch, isTrain: True})
      D_losses.append(np.mean(dloss))

      z_batch = np.random.normal(0, 1, (batch_size, 1, 1, 100))
      for _ in range(g_iterations):
        #Update generator, calculate and append its loss
        gloss, _ = sess.run([G_loss, G_optim], {z: z_batch, x: x_batch, isTrain: True})
      G_losses.append(np.mean(gloss))

    fixed_z = np.random.normal(0, 1, (25, 1, 1, 100))
    #Generate sample and append it in samples 
    sample= sess.run(G_z, {z: fixed_z, isTrain: False})
    samples.append(sample)
    
    #Append the training loss of each epoch 
    training_loss['D_losses'].append(np.mean(D_losses))
    training_loss['G_losses'].append(np.mean(G_losses))

    #Print the training loss in each epoch by taking the average of batches losses 
    print("Iterations: %d\t Discriminator loss: %.4f\t Generator loss: %.4f"%(epoch+1,
                                                                              np.mean(D_losses),
                                                                              np.mean(G_losses)))
sess.close()
# Out:
# Iterations: 1	 Discriminator loss: 1.2631	 Generator loss: 0.3397
# Iterations: 2	 Discriminator loss: 1.1614	 Generator loss: 0.3645
# Iterations: 3	 Discriminator loss: 1.1070	 Generator loss: 0.4068
# Iterations: 4	 Discriminator loss: 1.1041	 Generator loss: 0.4181
# Iterations: 5	 Discriminator loss: 1.0795	 Generator loss: 0.4001
# Iterations: 6	 Discriminator loss: 1.0825	 Generator loss: 0.3461
# Iterations: 7	 Discriminator loss: 1.1037	 Generator loss: 0.3265
# Iterations: 8	 Discriminator loss: 1.0815	 Generator loss: 0.3174
# Iterations: 9	 Discriminator loss: 1.0323	 Generator loss: 0.2882
# Iterations: 10	 Discriminator loss: 1.0353	 Generator loss: 0.2937
# Iterations: 11	 Discriminator loss: 0.9730	 Generator loss: 0.2733
# Iterations: 12	 Discriminator loss: 0.9405	 Generator loss: 0.2713
# Iterations: 13	 Discriminator loss: 0.9139	 Generator loss: 0.2610
# Iterations: 14	 Discriminator loss: 0.8366	 Generator loss: 0.2594
# Iterations: 15	 Discriminator loss: 0.7985	 Generator loss: 0.2488
# Iterations: 16	 Discriminator loss: 0.8104	 Generator loss: 0.2306
# Iterations: 17	 Discriminator loss: 0.7980	 Generator loss: 0.2275
# Iterations: 18	 Discriminator loss: 0.7225	 Generator loss: 0.2259
# Iterations: 19	 Discriminator loss: 0.6804	 Generator loss: 0.1989
# Iterations: 20	 Discriminator loss: 0.6613	 Generator loss: 0.2151
# Iterations: 21	 Discriminator loss: 0.6481	 Generator loss: 0.2215
# Iterations: 22	 Discriminator loss: 0.6053	 Generator loss: 0.2079
# Iterations: 23	 Discriminator loss: 0.5162	 Generator loss: 0.1848
# Iterations: 24	 Discriminator loss: 0.5034	 Generator loss: 0.1897
# Iterations: 25	 Discriminator loss: 0.5080	 Generator loss: 0.1802
# Iterations: 26	 Discriminator loss: 0.4687	 Generator loss: 0.1786
# Iterations: 27	 Discriminator loss: 0.4637	 Generator loss: 0.1768
# Iterations: 28	 Discriminator loss: 0.4209	 Generator loss: 0.1708
# Iterations: 29	 Discriminator loss: 0.4199	 Generator loss: 0.1618
# Iterations: 30	 Discriminator loss: 0.4004	 Generator loss: 0.1576
# Iterations: 31	 Discriminator loss: 0.3713	 Generator loss: 0.1610
# Iterations: 32	 Discriminator loss: 0.3890	 Generator loss: 0.1590
# Iterations: 33	 Discriminator loss: 0.3499	 Generator loss: 0.1472
# Iterations: 34	 Discriminator loss: 0.3507	 Generator loss: 0.1791
# Iterations: 35	 Discriminator loss: 0.3113	 Generator loss: 0.1565
# Iterations: 36	 Discriminator loss: 0.2649	 Generator loss: 0.1482
# Iterations: 37	 Discriminator loss: 0.3003	 Generator loss: 0.1637
# Iterations: 38	 Discriminator loss: 0.2935	 Generator loss: 0.1619
# Iterations: 39	 Discriminator loss: 0.2441	 Generator loss: 0.1563
# Iterations: 40	 Discriminator loss: 0.2420	 Generator loss: 0.1671
# Iterations: 41	 Discriminator loss: 0.2421	 Generator loss: 0.1682
# Iterations: 42	 Discriminator loss: 0.2170	 Generator loss: 0.1605
# Iterations: 43	 Discriminator loss: 0.2009	 Generator loss: 0.1534
# Iterations: 44	 Discriminator loss: 0.2172	 Generator loss: 0.1520
# Iterations: 45	 Discriminator loss: 0.2064	 Generator loss: 0.1644
# Iterations: 46	 Discriminator loss: 0.2087	 Generator loss: 0.1516
# Iterations: 47	 Discriminator loss: 0.1867	 Generator loss: 0.1401
# Iterations: 48	 Discriminator loss: 0.2130	 Generator loss: 0.1524
# Iterations: 49	 Discriminator loss: 0.1832	 Generator loss: 0.1571
# Iterations: 50	 Discriminator loss: 0.1914	 Generator loss: 0.1457
# Iterations: 51	 Discriminator loss: 0.1490	 Generator loss: 0.1403
# Iterations: 52	 Discriminator loss: 0.1590	 Generator loss: 0.1516
# Iterations: 53	 Discriminator loss: 0.1498	 Generator loss: 0.1454
# Iterations: 54	 Discriminator loss: 0.1738	 Generator loss: 0.1522
# Iterations: 55	 Discriminator loss: 0.1343	 Generator loss: 0.1374
# Iterations: 56	 Discriminator loss: 0.1331	 Generator loss: 0.1455
# Iterations: 57	 Discriminator loss: 0.1434	 Generator loss: 0.1347
# Iterations: 58	 Discriminator loss: 0.1297	 Generator loss: 0.1288
# Iterations: 59	 Discriminator loss: 0.1503	 Generator loss: 0.1318
# Iterations: 60	 Discriminator loss: 0.1086	 Generator loss: 0.1338
# Iterations: 61	 Discriminator loss: 0.1203	 Generator loss: 0.1561
# Iterations: 62	 Discriminator loss: 0.1037	 Generator loss: 0.1383
# Iterations: 63	 Discriminator loss: 0.1057	 Generator loss: 0.1309
# Iterations: 64	 Discriminator loss: 0.1189	 Generator loss: 0.1358
# Iterations: 65	 Discriminator loss: 0.1198	 Generator loss: 0.1441
# Iterations: 66	 Discriminator loss: 0.1202	 Generator loss: 0.1493
# Iterations: 67	 Discriminator loss: 0.1284	 Generator loss: 0.1376
# Iterations: 68	 Discriminator loss: 0.0914	 Generator loss: 0.1392
# Iterations: 69	 Discriminator loss: 0.1046	 Generator loss: 0.1328
# Iterations: 70	 Discriminator loss: 0.0905	 Generator loss: 0.1509
# Iterations: 71	 Discriminator loss: 0.1026	 Generator loss: 0.1462
# Iterations: 72	 Discriminator loss: 0.1007	 Generator loss: 0.1410
# Iterations: 73	 Discriminator loss: 0.0956	 Generator loss: 0.1258
# Iterations: 74	 Discriminator loss: 0.0924	 Generator loss: 0.1364
# Iterations: 75	 Discriminator loss: 0.0824	 Generator loss: 0.1444
# Iterations: 76	 Discriminator loss: 0.0792	 Generator loss: 0.1392
# Iterations: 77	 Discriminator loss: 0.0879	 Generator loss: 0.1663
# Iterations: 78	 Discriminator loss: 0.0777	 Generator loss: 0.1426
# Iterations: 79	 Discriminator loss: 0.0946	 Generator loss: 0.1268
# Iterations: 80	 Discriminator loss: 0.0717	 Generator loss: 0.1334
# Iterations: 81	 Discriminator loss: 0.0614	 Generator loss: 0.1239
# Iterations: 82	 Discriminator loss: 0.0984	 Generator loss: 0.1353
# Iterations: 83	 Discriminator loss: 0.0694	 Generator loss: 0.1279
# Iterations: 84	 Discriminator loss: 0.0609	 Generator loss: 0.1162
# Iterations: 85	 Discriminator loss: 0.0516	 Generator loss: 0.1326
# Iterations: 86	 Discriminator loss: 0.0545	 Generator loss: 0.1241
# Iterations: 87	 Discriminator loss: 0.0549	 Generator loss: 0.1098
# Iterations: 88	 Discriminator loss: 0.0532	 Generator loss: 0.1247
# Iterations: 89	 Discriminator loss: 0.0572	 Generator loss: 0.1569
# Iterations: 90	 Discriminator loss: 0.0614	 Generator loss: 0.1376
# Iterations: 91	 Discriminator loss: 0.0624	 Generator loss: 0.1264
# Iterations: 92	 Discriminator loss: 0.0617	 Generator loss: 0.1160
# Iterations: 93	 Discriminator loss: 0.0761	 Generator loss: 0.1244
# Iterations: 94	 Discriminator loss: 0.0551	 Generator loss: 0.1205
# Iterations: 95	 Discriminator loss: 0.0462	 Generator loss: 0.1301
# Iterations: 96	 Discriminator loss: 0.0578	 Generator loss: 0.1230
# Iterations: 97	 Discriminator loss: 0.0579	 Generator loss: 0.1325
# Iterations: 98	 Discriminator loss: 0.0533	 Generator loss: 0.1412
# Iterations: 99	 Discriminator loss: 0.0426	 Generator loss: 0.1359
# Iterations: 100	 Discriminator loss: 0.0373	 Generator loss: 0.1290

# %%
#Plot training loss for both generator and discriminator 
plot_training_loss(training_loss)

# %%
#Plot sample of the first epoch
plot_samples(samples, epoch=0)

# %%
#Plot sample of the last epoch
plot_samples(samples)
