# %% [markdown]
# # Select TensorFlow 1

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
from tensorflow.layers import conv2d, conv2d_transpose, batch_normalization
from tensorflow.nn import tanh, sigmoid, leaky_relu, sigmoid_cross_entropy_with_logits
from tensorflow.train import AdamOptimizer

# %% [markdown]
# # Defining model layers

# %% [markdown]
# ### Defining generator model for the GAN

# %%
def generator(x, isTrain=True, reuse=False):
    with tf.variable_scope('generator', reuse=reuse):

        # 1st hidden layer
        conv1 = conv2d_transpose(x, 1024, [4, 4], strides=(1, 1), padding='valid')
        lrelu1 = leaky_relu(batch_normalization(conv1, training=isTrain))

        # 2nd hidden layer
        conv2 = conv2d_transpose(lrelu1, 512, [4, 4], strides=(2, 2), padding='same')
        lrelu2 = leaky_relu(batch_normalization(conv2, training=isTrain))

        # 3rd hidden layer
        conv3 = conv2d_transpose(lrelu2, 256, [4, 4], strides=(2, 2), padding='same')
        lrelu3 = leaky_relu(batch_normalization(conv3, training=isTrain))

        # 4th hidden layer
        conv4 = conv2d_transpose(lrelu3, 128, [4, 4], strides=(2, 2), padding='same')
        lrelu4 = leaky_relu(batch_normalization(conv4, training=isTrain))

        # output layer
        conv5 = conv2d_transpose(lrelu4, 1, [4, 4], strides=(2, 2), padding='same')
        output = tanh(conv5)

        return output

# %% [markdown]
# ### Defining discriminator model for the GAN

# %%
def discriminator(x, isTrain=True, reuse=False):
    with tf.variable_scope('discriminator', reuse=reuse):
        # 1st hidden layer
        conv1 = conv2d(x, 128, [4, 4], strides=(2, 2), padding='same')
        lrelu1 = leaky_relu(conv1)

        # 2nd hidden layer
        conv2 = conv2d(lrelu1, 256, [4, 4], strides=(2, 2), padding='same')
        lrelu2 = leaky_relu(tf.layers.batch_normalization(conv2, training=isTrain))

        # 3rd hidden layer
        conv3 = conv2d(lrelu2, 512, [4, 4], strides=(2, 2), padding='same')
        lrelu3 = leaky_relu(tf.layers.batch_normalization(conv3, training=isTrain))

        # 4th hidden layer
        conv4 = conv2d(lrelu3, 1024, [4, 4], strides=(2, 2), padding='same')
        lrelu4 = leaky_relu(tf.layers.batch_normalization(conv4, training=isTrain))

        # output layer
        conv5 = conv2d(lrelu4, 1, [4, 4], strides=(1, 1), padding='valid')
        output = sigmoid(conv5)

        return output, conv5

# %% [markdown]
# # Defining GAN models

# %%
def create_GAN(x, z, isTrain):
  G_sample = generator(z, isTrain)
  D_real, D_real_logits= discriminator(x, isTrain)
  D_fake, D_fake_logits = discriminator(G_sample, isTrain, reuse=True)
  return G_sample, D_real, D_real_logits ,D_fake, D_fake_logits

# %% [markdown]
# # Defining losses for the network models

# %%
def create_loss_functions(D_real_logits, D_fake_logits, batch_size):
  D_loss_real = tf.reduce_mean(
      sigmoid_cross_entropy_with_logits(logits=D_real_logits, labels=tf.ones([batch_size, 1, 1, 1])))
  D_loss_fake = tf.reduce_mean(
      sigmoid_cross_entropy_with_logits(logits=D_fake_logits, labels=tf.zeros([batch_size, 1, 1, 1])))
  D_loss = D_loss_real + D_loss_fake
  G_loss = tf.reduce_mean(
      sigmoid_cross_entropy_with_logits(logits=D_fake_logits, labels=tf.ones([batch_size, 1, 1, 1])))
  return D_loss, G_loss

# %% [markdown]
# # Util functions

# %%
#Define the plot of sample result function
def plot_samples(samples, epoch=None, n=5):
  if epoch == None:
    epoch = np.shape(samples)[0]-1
  fig = plt.figure(figsize=(8, 8))
  for i in range(n*n):
      ax = plt.subplot(n, n, i + 1)
      ax.imshow(samples[epoch][i].reshape(64,64))
      ax.axis("off")
  fig.subplots_adjust(hspace=0.025, wspace=0.025)
  plt.show()

# %%
#Define the plot of the training loss
def plot_training_loss(training_loss):
  plt.plot(training_loss['G_losses'], label='G_loss' )
  plt.plot(training_loss['D_losses'], label='D_loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(loc=1)
  plt.grid(True) 
  plt.show()

# %% [markdown]
# # Loading data, defining training parameters and input variables

# %%
# training parameters
lr = 0.0002
batch_size = 100
num_epochs = 100

# load MNIST
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True, reshape=[])

# input variables
x = tf.placeholder(tf.float32, shape=(None, 64, 64, 1))
z = tf.placeholder(tf.float32, shape=(None, 1, 1, 100))
isTrain = tf.placeholder(dtype=tf.bool)
# Out:
# WARNING:tensorflow:From <ipython-input-9-d92218167693>:7: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# # Initializing the GAN network

# %%
#Create GAN 
G_z, D_real, D_real_logits, D_fake, D_fake_logits = create_GAN(x, z, isTrain)
# Out:
# WARNING:tensorflow:From <ipython-input-3-695fb557b739>:5: conv2d_transpose (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2DTranspose` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/convolutional.py:1279: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From <ipython-input-3-695fb557b739>:6: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# WARNING:tensorflow:From <ipython-input-4-5476eab2b3a9>:4: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.

# %% [markdown]
# # Initializing losses for each network

# %%
#Create loss function for each network
D_loss, G_loss = create_loss_functions(D_real_logits,D_fake_logits,batch_size)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# # Model Setup

# %%
# trainable variables for each network
T_vars = tf.trainable_variables()
D_vars = [var for var in T_vars if var.name.startswith('discriminator')]
G_vars = [var for var in T_vars if var.name.startswith('generator')]

# Optimizer for each network
with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
    D_optim = tf.train.AdamOptimizer(lr, beta1=0.5).minimize(D_loss, var_list=D_vars)
    G_optim = tf.train.AdamOptimizer(lr, beta1=0.5).minimize(G_loss, var_list=G_vars)

# open session and initialize all variables
sess = tf.InteractiveSession()
tf.global_variables_initializer().run()


# Resize the data to be 64 * 64
train_set = tf.image.resize_images(mnist.train.images, [64, 64]).eval()

# Normalize the data to be from -1:1 
train_set = (train_set - 0.5) * 2 

#Initialize the training loss 
training_loss = {}
training_loss['D_losses'] = []
training_loss['G_losses'] = []

#Take a slice of the data to train on it to reduce the time of the training 
data_slice = 2000
train_set = train_set[:data_slice,:]

#Initialize the training loss 
training_loss = {}
training_loss['D_losses'] = []
training_loss['G_losses'] = []

#Initialize samples that will be used for ploting
samples=[]

# %% [markdown]
# # Training model

# %%
#Loop over the number of epochs 
for epoch in range(num_epochs):
    #Initialize discriminator loss (D_losses) and generator loss (G_losses) with an empty list in each epoch
    D_losses = []
    G_losses = []

    #Loop over the number of mini batches 
    mini_batches = train_set.shape[0] // batch_size
    for batch in range(mini_batches):

      x_batch = train_set[batch*batch_size:(batch+1)*batch_size]
      z_batch = np.random.normal(0, 1, (batch_size, 1, 1, 100))
      #Update discriminator, calculate and append its loss
      dloss, _ = sess.run([D_loss, D_optim], {x: x_batch, z: z_batch, isTrain: True})
      D_losses.append(np.mean(dloss))

      z_batch = np.random.normal(0, 1, (batch_size, 1, 1, 100))
      #Update generator, calculate and append its loss
      gloss, _ = sess.run([G_loss, G_optim], {z: z_batch, x: x_batch, isTrain: True})
      G_losses.append(gloss)

    fixed_z = np.random.normal(0, 1, (25, 1, 1, 100))
    #Generate sample and append it to samples 
    sample= sess.run(G_z, {z: fixed_z, isTrain: False})
    samples.append(sample)
    
    #Append the training loss of each epoch 
    training_loss['D_losses'].append(np.mean(D_losses))
    training_loss['G_losses'].append(np.mean(G_losses))

    #Print the training loss in each epoch by taking the average of batches losses 
    print("Epoch: %d\t Discriminator loss: %.4f\t Generator loss: %.4f"%(epoch+1,
                                                                              np.mean(D_losses),
                                                                              np.mean(G_losses)))
sess.close()
# Out:
# Epoch: 1	 Discriminator loss: 1.4303	 Generator loss: 25.7937
# Epoch: 2	 Discriminator loss: 3.6448	 Generator loss: 18.0414
# Epoch: 3	 Discriminator loss: 0.7748	 Generator loss: 4.2698
# Epoch: 4	 Discriminator loss: 1.2073	 Generator loss: 4.4787
# Epoch: 5	 Discriminator loss: 0.7365	 Generator loss: 3.4684
# Epoch: 6	 Discriminator loss: 0.8620	 Generator loss: 3.3936
# Epoch: 7	 Discriminator loss: 0.9867	 Generator loss: 3.1538
# Epoch: 8	 Discriminator loss: 0.2984	 Generator loss: 3.1683
# Epoch: 9	 Discriminator loss: 1.1547	 Generator loss: 3.1136
# Epoch: 10	 Discriminator loss: 0.2660	 Generator loss: 3.1962
# Epoch: 11	 Discriminator loss: 0.2312	 Generator loss: 3.5137
# Epoch: 12	 Discriminator loss: 3.5238	 Generator loss: 3.5100
# Epoch: 13	 Discriminator loss: 0.9300	 Generator loss: 1.9607
# Epoch: 14	 Discriminator loss: 0.6688	 Generator loss: 2.3161
# Epoch: 15	 Discriminator loss: 0.3367	 Generator loss: 2.9944
# Epoch: 16	 Discriminator loss: 0.2866	 Generator loss: 3.3778
# Epoch: 17	 Discriminator loss: 0.1243	 Generator loss: 3.7389
# Epoch: 18	 Discriminator loss: 0.1062	 Generator loss: 3.7457
# Epoch: 19	 Discriminator loss: 1.5413	 Generator loss: 2.7271
# Epoch: 20	 Discriminator loss: 1.0922	 Generator loss: 1.6186
# Epoch: 21	 Discriminator loss: 0.9586	 Generator loss: 1.8727
# Epoch: 22	 Discriminator loss: 0.9301	 Generator loss: 2.1320
# Epoch: 23	 Discriminator loss: 0.7088	 Generator loss: 2.2141
# Epoch: 24	 Discriminator loss: 0.5828	 Generator loss: 2.6233
# Epoch: 25	 Discriminator loss: 0.5995	 Generator loss: 2.6263
# Epoch: 26	 Discriminator loss: 0.6463	 Generator loss: 3.1090
# Epoch: 27	 Discriminator loss: 0.4677	 Generator loss: 2.6109
# Epoch: 28	 Discriminator loss: 0.5306	 Generator loss: 2.8837
# Epoch: 29	 Discriminator loss: 0.8826	 Generator loss: 3.4406
# Epoch: 30	 Discriminator loss: 1.1376	 Generator loss: 1.9261
# Epoch: 31	 Discriminator loss: 0.6536	 Generator loss: 2.2307
# Epoch: 32	 Discriminator loss: 0.4520	 Generator loss: 2.6358
# Epoch: 33	 Discriminator loss: 0.2331	 Generator loss: 2.9971
# Epoch: 34	 Discriminator loss: 1.8588	 Generator loss: 2.1605
# Epoch: 35	 Discriminator loss: 0.6893	 Generator loss: 1.9783
# Epoch: 36	 Discriminator loss: 0.4336	 Generator loss: 2.5636
# Epoch: 37	 Discriminator loss: 0.2791	 Generator loss: 2.9333
# Epoch: 38	 Discriminator loss: 0.6943	 Generator loss: 3.5321
# Epoch: 39	 Discriminator loss: 0.7625	 Generator loss: 2.1244
# Epoch: 40	 Discriminator loss: 0.3884	 Generator loss: 2.6218
# Epoch: 41	 Discriminator loss: 1.1440	 Generator loss: 2.8914
# Epoch: 42	 Discriminator loss: 0.7599	 Generator loss: 2.3273
# Epoch: 43	 Discriminator loss: 0.4656	 Generator loss: 2.6080
# Epoch: 44	 Discriminator loss: 0.3292	 Generator loss: 3.0243
# Epoch: 45	 Discriminator loss: 0.1663	 Generator loss: 3.5816
# Epoch: 46	 Discriminator loss: 0.5829	 Generator loss: 3.1241
# Epoch: 47	 Discriminator loss: 0.1952	 Generator loss: 3.5256
# Epoch: 48	 Discriminator loss: 0.8816	 Generator loss: 3.0494
# Epoch: 49	 Discriminator loss: 0.2392	 Generator loss: 3.6203
# Epoch: 50	 Discriminator loss: 0.6737	 Generator loss: 3.2841
# Epoch: 51	 Discriminator loss: 0.2371	 Generator loss: 3.3984
# Epoch: 52	 Discriminator loss: 0.1308	 Generator loss: 4.0299
# Epoch: 53	 Discriminator loss: 0.0798	 Generator loss: 4.6193
# Epoch: 54	 Discriminator loss: 0.0633	 Generator loss: 4.6251
# Epoch: 55	 Discriminator loss: 1.7668	 Generator loss: 4.1830
# Epoch: 56	 Discriminator loss: 0.7405	 Generator loss: 2.4931
# Epoch: 57	 Discriminator loss: 0.3706	 Generator loss: 2.9593
# Epoch: 58	 Discriminator loss: 0.3483	 Generator loss: 3.3500
# Epoch: 59	 Discriminator loss: 0.1680	 Generator loss: 3.8378
# Epoch: 60	 Discriminator loss: 0.6740	 Generator loss: 4.2042
# Epoch: 61	 Discriminator loss: 0.6146	 Generator loss: 2.9160
# Epoch: 62	 Discriminator loss: 1.2207	 Generator loss: 3.0372
# Epoch: 63	 Discriminator loss: 1.1710	 Generator loss: 1.8433
# Epoch: 64	 Discriminator loss: 0.6772	 Generator loss: 2.6036
# Epoch: 65	 Discriminator loss: 0.4340	 Generator loss: 3.2510
# Epoch: 66	 Discriminator loss: 0.1820	 Generator loss: 3.9094
# Epoch: 67	 Discriminator loss: 0.0874	 Generator loss: 4.2770
# Epoch: 68	 Discriminator loss: 0.0615	 Generator loss: 4.8894
# Epoch: 69	 Discriminator loss: 0.0591	 Generator loss: 5.1165
# Epoch: 70	 Discriminator loss: 0.0407	 Generator loss: 5.3371
# Epoch: 71	 Discriminator loss: 0.0410	 Generator loss: 5.2056
# Epoch: 72	 Discriminator loss: 0.0323	 Generator loss: 5.3247
# Epoch: 73	 Discriminator loss: 1.4644	 Generator loss: 2.5799
# Epoch: 74	 Discriminator loss: 1.1222	 Generator loss: 2.1161
# Epoch: 75	 Discriminator loss: 0.8751	 Generator loss: 2.2904
# Epoch: 76	 Discriminator loss: 0.7341	 Generator loss: 2.4705
# Epoch: 77	 Discriminator loss: 0.7215	 Generator loss: 2.7549
# Epoch: 78	 Discriminator loss: 0.3834	 Generator loss: 2.9481
# Epoch: 79	 Discriminator loss: 1.2127	 Generator loss: 3.2193
# Epoch: 80	 Discriminator loss: 0.8272	 Generator loss: 2.2788
# Epoch: 81	 Discriminator loss: 0.3775	 Generator loss: 3.0845
# Epoch: 82	 Discriminator loss: 0.2569	 Generator loss: 3.5046
# Epoch: 83	 Discriminator loss: 0.1455	 Generator loss: 4.1204
# Epoch: 84	 Discriminator loss: 0.0718	 Generator loss: 4.6149
# Epoch: 85	 Discriminator loss: 0.0435	 Generator loss: 5.0517
# Epoch: 86	 Discriminator loss: 0.0504	 Generator loss: 5.4043
# Epoch: 87	 Discriminator loss: 0.0248	 Generator loss: 5.6031
# Epoch: 88	 Discriminator loss: 0.0290	 Generator loss: 5.4632
# Epoch: 89	 Discriminator loss: 0.0242	 Generator loss: 5.7185
# Epoch: 90	 Discriminator loss: 0.2900	 Generator loss: 5.8028
# Epoch: 91	 Discriminator loss: 1.4569	 Generator loss: 2.1190
# Epoch: 92	 Discriminator loss: 0.4204	 Generator loss: 3.2902
# Epoch: 93	 Discriminator loss: 0.5955	 Generator loss: 3.6833
# Epoch: 94	 Discriminator loss: 0.8694	 Generator loss: 3.0513
# Epoch: 95	 Discriminator loss: 0.4080	 Generator loss: 3.7146
# Epoch: 96	 Discriminator loss: 0.3233	 Generator loss: 4.1467
# Epoch: 97	 Discriminator loss: 0.4355	 Generator loss: 3.8361
# Epoch: 98	 Discriminator loss: 0.1530	 Generator loss: 4.4663
# Epoch: 99	 Discriminator loss: 0.0605	 Generator loss: 4.8871
# Epoch: 100	 Discriminator loss: 0.0342	 Generator loss: 5.5346

# %%
#Plot training loss for both generator and discriminator 
plot_training_loss(training_loss)

# %%
#Plot sample of the first epoch
plot_samples(samples, epoch=0)

# %%
#Plot sample of the last epoch
plot_samples(samples)
